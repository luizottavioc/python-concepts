# %% [markdown]
# # Pandas
# Pandas é uma biblioteca Python de código aberto para análise de dados, que oferece alto desempenho, estruturas de dados de fácil utilização e ferramentas de análise de dados. Para usar a biblioteca, basta utilizar o seguinte comando de importação abaixo:
#
# ```python
# import numpy as np
# import pandas as pd
# ```

# %% [markdown]
# ## Obtendo os Dados
#
# | Formato | Descrição                        |  Função de Leitura | Função de Escrita |
# |:--------|:---------------------------------|:-------------------|:------------------|
# | Texto   | CSV                              | read_csv( )        | to_csv( )         |
# | Texto   | JSON                             | read_json( )       | to_json( )        |
# | Texto   | HTML                             | read_html( )       | to_html( )        |
# | Texto   | Área de Transferência de Memória | read_clipboard( )  | to_clipboard( )   |
# | Binário | MS Excel                         | read_excel( )      | to_excel( )       |
# | Binário | HDF5 Format                      | read_hdf( )        | to_hdf( )         |
# | Binário | Feather Format                   | read_feather( )    | to_feather( )     |
# | Binário | Parquet Format                   | read_parquet( )    | to_parquet( )     |
# | Binário | Msgpack                          | read_msgpack( )    | to_msgpack( )     |
# | Binário | Stata                            | read_stata( )      | to_stata( )       |
# | Binário | SAS                              | read_sas( )        | -                 |
# | Binário | Python Pickle Format             | read_pickle( )     | to_pickle( )      |
# | SQL     | SQL                              | read_sql( )        | to_sql( )         |
# | SQL     | Google Big Query                 | read_gbq( )        | to_gbq( )         |
#
# ### Exemplos
#
# ```python
# # Exemplo 1: Leitura e Escrita para CSV
#
# # Lê 5 linhas de um arquivo CSV sem cabeçalho.
# pd.read_csv("arquivo.csv", header=None, nrows=5)
#
# # Exporta os dados de uma estrutura de dados
# # Data Frame do Pandas para um arquivo csv.
# dados_data_frame.to_csv("dados_data_frame.csv")
#
#
# # Exemplo 2: Leitura e Escrita para EXCEL
# pd.read_excel("planilha.xlsx")
#
# dados_data_frame.to_excel("dados_data_frame.xlsx", sheet_name="Planilha 1")
#
# # Carrega múltiplas planilhas do mesmo arquivo
# planilha = pd.ExcelFile("arquivo.xls")
# dados_data_frame = pd.read_excel(xlsx, "Planilha 1")
# ```

# %% [markdown]
# ## Estruturas de Dados
#
# ### Series
# Vetor unidimensional rotulado capaz de armazenar qualquer tipo de dado

# %%
import numpy as np
import pandas as pd

s = pd.Series(np.random.randn(5), index=['a', 'b', 'c', 'd', 'e'])
s

# %% [markdown]
# ### Data Frame
# Matriz rotulada contendo colunas com diferentes tipos de dados

# %%
data = {
    'Country': ['Belgium',  'India',  'Brazil'],
    'Capital': ['Brussels',  'New Delhi',  'Brasilia'],
    'Population': [11190846, 1303171035, 207847528]
}

df = pd.DataFrame(data, columns=['Country',  'Capital',  'Population'])

df

# %% [markdown]
# ### Indexação / Seleção
#
# | Operação                                    | Sintaxe            | Resultado |
# |:--------------------------------------------|:-------------------|:----------|
# | Seleciona Coluna                            | df[col]            | Series    |
# | Seleciona Linha por nome do rótulo          | df.loc[rotulo]     | Series    |
# | Seleciona linhas por posição (inteiro)      | df.iloc[posicao]   | Series    |
# | Divide Linhas                               | df[5:10]           | DataFrame |
# | Seleciona linhas por vetor booleano         | df[vetor_booleano] | DataFrame |

# %%
import numpy as np
import pandas as pd

data = {
    'Country': ['Belgium',  'India',  'Brazil'],
    'Capital': ['Brussels',  'New Delhi',  'Brasilia'],
    'Population': [11190846, 1303171035, 207847528]
}

df = pd.DataFrame(data, columns=['Country',  'Capital',  'Population'])

# Seleção por posição
df.iloc[[0],[0]]

# Seleção por rótulo
df.loc[[0], ['Country']]

# Rótulo/Posição
df.loc[2]
df.loc[:, 'Capital']
df.loc[2, 'Capital']

# %% [markdown]
# ### Missing Data (Dados Ausentes)
#
# O pandas utiliza o valor np.nan para representar todos os dados auentes que possam aparecer no conjunto de dados. Para detectar dados ausentes facilmente, o Pandas fornece as funções: isna() e notna(), que são também métodos dos objetos do tipo Series e DataFrame.

# %%
import numpy as np
import pandas as pd

df = pd.DataFrame(np.random.randn(5, 3), index=['A', 'C', 'E', 'F', 'H'], 
                  columns=['one', 'two', 'three'])

df['four'] = 'bar' # Cria uma nova coluna (four) e adiciona valores constantes (bar)
df['five'] = df['one'] > 0 # Cria uma nova coluna (five) e adiciona true se a coluna 1 for maior que zero
df

# Reindexa o data frame para simularmos os missing datas
# Ele adicionou as linhas ausentes: B, D e G; e preencheu
# com dados auentes (NaN)
df2 = df.reindex(['A', 'B', 'C', 'D', 'E', 'F', 'G', 'H'])

# Avalia o data frame e coloca True no local dos dados ausentes
df2
pd.isna(df2)
df2.isna()

# É possível fazer o teste especificando colunas
df2['one']
pd.isna(df2['one']) 
df2['four'].notna()

# %% [markdown]
# ### Ordenação e Ranking
#
# | Função                          | Descrição                        |
# |:--------------------------------|:---------------------------------|
# | df.sort_index()                 | Ordena por índices               |
# | df.sort_values(by='NomeColuna') | Ordena por valores               |
# | df.rank()                       | Gera um ranking para as entradas |
#
#
# ### Informações Básicas
#
# | Função         | Descrição                                |
# |:---------------|:-----------------------------------------|
# | df.shape()     | Retorna (linhas, colunas)                |
# | df.index()     | Descreve os índices                      |
# | df.columns()   | Descreve as colunas do Data Frame        |
# | df.info()      | Informações do Data Frame                |
# | df.count()     | Retorna a contagem dos valores não nulos |
#
#
# ### Sumário Quantitativo
#
# | Função         | Descrição                      |
# |:---------------|:-------------------------------|
# | df.sum()       | Soma dos valores               |
# | df.cumsum()    | Soma cumulativa dos valores    |
# | df.min()       | Obtém o valor mínimo           |
# | df.max()       | Obtém o valor máximo           |
# | df.idxmin()    | Obtém o valor mínimo do índice |
# | df.idxmax()    | Obtém o valor máximo do índice |
# | df.describe()  | Gera estatísticas descritivas que resumem a tendência central, a dispersão e a forma da distribuição de um conjunto de dados, excluindo os valores NaN. |
# | df.mean()      | Calcula a Média                |
# | df.median()    | Calcula a Mediana              |

# %% [markdown]
# ## Aprendendo Pandas na Prática
#
# Considerando o famoso conjunto de dados: [**Dados de 93 carros à venda nos EUA em 1993**](https://stat.ethz.ch/R-manual/R-devel/library/MASS/html/Cars93.html) disponível na pasta [`data/carros_93.csv`](data/carros_93.csv), faremos algumas tarefas rotineiras de um cientista de dados utilizando a biblioteca Pandas.
#
# ### Dicionário de Dados

# %% [markdown]
# | Nº | Coluna                      | Descrição                                                 |
# |:--:|:----------------------------|:----------------------------------------------------------|
# |  1 | fabricante                  | Fabricante do carro.                                      |
# |  2 | modelo                      | Modelo do carro.                                          |
# |  3 | tipo                        | Pequeno, Esportivo, Compacto, Médio, Grande ou Van.       |
# |  4 | preco_min                   | Preço mínimo em dólares para uma versão básica.           |
# |  5 | preco                       | Preço médio em dólares para uma versão básica.            |
# |  6 | preco_max                   | Preço máximo em dólares para uma versão básica.           |
# |  7 | mpg_cidade                  | Consumo em Milhas por Galão (MPG) na cidade.              |
# |  8 | mpg_rodovia                 | Consumo em Milhas por Galão (MPG) na estrada.             |
# |  9 | airbags                     | Nenhum, Somente Motorista ou Motorista e Passageiro.      |
# | 10 | tracao                      | Traseira, Dianteira ou 4x4                                |
# | 11 | cilindros                   | Número de cilindros                                       |
# | 12 | tamanho_motor               | Tamanho do motor em litros                                |
# | 13 | horsepower                  | Cavalos-força (máximo).                                   |
# | 14 | rpm                         | RPM (rotações por minuto na potência máxima).             |
# | 15 | revolucoes_milha            | Rotações do motor por milha (na marcha mais alta).        |
# | 16 | transmissao_manual          | Possui transmissão manual?                                |
# | 17 | capacidade_tanque           | Capacidade do tanque de combustível em galões americanos. |
# | 18 | passageiros                 | Capacidade de passageiros (pessoas)                       |
# | 19 | comprimento_in              | Comprimento (polegadas).                                  |
# | 20 | distancia_eixo              | Distância entre eixos (polegadas).                        |
# | 21 | largura_in                  | Largura (polegadas).                                      |
# | 22 | espaco_inversao_marcha_ft   | Espaço em inversão de marcha (pés).                       |
# | 23 | tamanho_assento_traseiro_in | Tamanho do banco traseiro (polegadas).                    |
# | 24 | porta_mala_ft3              | Capacidade de bagagem (pés cúbicos)                       |
# | 25 | peso_lb                     | Peso (libras).                                            |
# | 26 | origem                      | Origem de empresas americanas ou fora dos EUA.            |
# | 27 | fabricante_modelo           | Combinação de fabricante e modelo.                        |
#
# Os carros foram selecionados aleatoriamente entre os modelos de automóveis de passageiros de 1993 listados na edição do Consumer Reports e no PACE Buying Guide. As caminhonetes e os veículos esportivos/utilitários foram eliminados devido a informações incompletas na fonte do Consumer Reports. Os modelos duplicados (por exemplo, Dodge Shadow e Plymouth Sundance) foram listados no máximo uma vez. Uma descrição mais detalhada pode ser encontrada em Lock (1993).
#
# #### Referências
#
# - Lock, R. H. (1993) 1993 New Car Data. Journal of Statistics Education 1(1). https://doi.org/10.1080/10691898.1993.11910459
# - Venables, W. N. and Ripley, B. D. (1999) Modern Applied Statistics with S-PLUS. Third Edition. Springer.

# %% [markdown]
# 1. Importe o pacote Pandas com o nome pd.

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# 2. Carregue em memória o conjunto de dados disponível na pasta [`data/carros_93.csv`](data/carros_93.csv) para uma variável chamada **df**.

# %%
df = pd.read_csv('data/carros93.csv')
df
# Out:
#     fabricante   modelo       tipo  preco_min  preco  preco_max  mpg_cidade  \
# 0        Acura  Integra    Pequeno       12.9   15.9       18.8        25.0
# 1          NaN   Legend      Médio       29.2   33.9       38.7        18.0
# 2         Audi       90   Compacto       25.9   29.1       32.3        20.0
# 3         Audi      100      Médio        NaN   37.7       44.6        19.0
# 4          BMW     535i      Médio        NaN   30.0        NaN        22.0
# ..         ...      ...        ...        ...    ...        ...         ...
# 88  Volkswagen  Eurovan        Van       16.6   19.7       22.7        17.0
# 89  Volkswagen   Passat   Compacto       17.6   20.0       22.4        21.0
# 90  Volkswagen  Corrado  Esportivo       22.9   23.3       23.7        18.0
# 91       Volvo      240   Compacto       21.8   22.7       23.5        21.0
# 92         NaN      850      Médio       24.8   26.7       28.5        20.0
#
#     mpg_rodovia                 airbags trem_forca  ...  passageiros  \
# 0          31.0                  Nenhum  Dianteiro  ...          5.0
# 1          25.0  Motorista e Passageiro  Dianteiro  ...          5.0
# 2          26.0       Somente Motorista  Dianteiro  ...          5.0
# 3          26.0  Motorista e Passageiro        NaN  ...          6.0
# 4          30.0                     NaN   Traseiro  ...          4.0
# ..          ...                     ...        ...  ...          ...
# 88         21.0                  Nenhum  Dianteiro  ...          7.0
# 89         30.0                  Nenhum  Dianteiro  ...          5.0
# 90         25.0                  Nenhum  Dianteiro  ...          4.0
# 91         28.0       Somente Motorista   Traseiro  ...          5.0
# 92         28.0  Motorista e Passageiro  Dianteiro  ...          5.0
#
#     comprimento_in  distancia_eixo  largura_in  espaco_inversao_marcha_ft  \
# 0            177.0           102.0        68.0                       37.0
# 1            195.0           115.0        71.0                       38.0
# 2            180.0           102.0        67.0                       37.0
# 3            193.0           106.0         NaN                       37.0
# 4            186.0           109.0        69.0                       39.0
# ..             ...             ...         ...                        ...
# 88           187.0           115.0        72.0                       38.0
# 89           180.0           103.0        67.0                       35.0
# 90           159.0            97.0        66.0                       36.0
# 91           190.0           104.0        67.0                       37.0
# 92           184.0           105.0        69.0                       38.0
#
#    tamanho_assento_traseiro_in  porta_mala_ft3  peso_lb        origem  \
# 0                         26.5             NaN   2705.0  Fora dos EUA
# 1                         30.0            15.0   3560.0  Fora dos EUA
# 2                         28.0            14.0   3375.0  Fora dos EUA
# 3                         31.0            17.0   3405.0  Fora dos EUA
# 4                         27.0            13.0   3640.0  Fora dos EUA
# ..                         ...             ...      ...           ...
# 88                        34.0             NaN   3960.0           NaN
# 89                        31.5            14.0   2985.0  Fora dos EUA
# 90                        26.0            15.0   2810.0  Fora dos EUA
# 91                        29.5            14.0   2985.0  Fora dos EUA
# 92                        30.0            15.0   3245.0  Fora dos EUA
#
#      fabricante_modelo
# 0        Acura Integra
# 1         Acura Legend
# 2              Audi 90
# 3             Audi 100
# 4             BMW 535i
# ..                 ...
# 88  Volkswagen Eurovan
# 89   Volkswagen Passat
# 90  Volkswagen Corrado
# 91           Volvo 240
# 92           Volvo 850
#
# [93 rows x 27 columns]

# %% [markdown]
# 3. Qual é o número de linhas e colunas?

# %%
print(f'Número de linhas: {df.shape[0]}')
print(f'Número de colunas: {df.shape[1]}')
# Out:
# Número de linhas: 93
# Número de colunas: 27

# %% [markdown]
# 4. Quais são os tipos de dados de cada uma das colunas?

# %%
df.dtypes
# Out:
# fabricante                      object
# modelo                          object
# tipo                            object
# preco_min                      float64
# preco                          float64
# preco_max                      float64
# mpg_cidade                     float64
# mpg_rodovia                    float64
# airbags                         object
# trem_forca                      object
# cilindros                      float64
# tamanho_motor                  float64
# horsepower                     float64
# rpm                            float64
# revolucoes_milha               float64
# transmissao_manual              object
# capacidade_tanque              float64
# passageiros                    float64
# comprimento_in                 float64
# distancia_eixo                 float64
# largura_in                     float64
# espaco_inversao_marcha_ft      float64
# tamanho_assento_traseiro_in    float64
# porta_mala_ft3                 float64
# peso_lb                        float64
# origem                          object
# fabricante_modelo               object
# dtype: object

# %% [markdown]
# 5. Mostre a quantidade de colunas para cada um dos tipos de dados.

# %%
df.dtypes.value_counts()
# Out:
# float64    19
# object      8
# dtype: int64

# %% [markdown]
# 6. Exiba um sumário estatístico do conjunto de dados.

# %%
df.describe()
# Out:
#        preco_min      preco  preco_max  mpg_cidade  mpg_rodovia  cilindros  \
# count  86.000000  91.000000  88.000000   84.000000    91.000000  87.000000
# mean   17.118605  19.616484  21.459091   22.404762    29.065934   5.000000
# std     8.828290   9.724280  10.696563    5.841520     5.370293   1.320676
# min     6.700000   7.400000   7.900000   15.000000    20.000000   3.000000
# 25%    10.825000  12.350000  14.575000   18.000000    26.000000   4.000000
# 50%    14.600000  17.700000  19.150000   21.000000    28.000000   4.000000
# 75%    20.250000  23.500000  24.825000   25.000000    31.000000   6.000000
# max    45.400000  61.900000  80.000000   46.000000    50.000000   8.000000
#
#        tamanho_motor  horsepower          rpm  revolucoes_milha  \
# count      91.000000   86.000000    90.000000         87.000000
# mean        2.658242  144.000000  5276.666667       2355.000000
# std         1.045845   53.455204   605.554811        486.916616
# min         1.000000   55.000000  3800.000000       1320.000000
# 25%         1.800000  100.750000  4800.000000       2017.500000
# 50%         2.300000  140.000000  5200.000000       2360.000000
# 75%         3.250000  170.000000  5787.500000       2565.000000
# max         5.700000  300.000000  6500.000000       3755.000000
#
#        capacidade_tanque  passageiros  comprimento_in  distancia_eixo  \
# count          85.000000    91.000000       89.000000       92.000000
# mean           16.683529     5.076923      182.865169      103.956522
# std             3.375748     1.045953       14.792651        6.856317
# min             9.200000     2.000000      141.000000       90.000000
# 25%            14.500000     4.000000      174.000000       98.000000
# 50%            16.500000     5.000000      181.000000      103.000000
# 75%            19.000000     6.000000      192.000000      110.000000
# max            27.000000     8.000000      219.000000      119.000000
#
#        largura_in  espaco_inversao_marcha_ft  tamanho_assento_traseiro_in  \
# count   87.000000                  88.000000                    89.000000
# mean    69.448276                  38.954545                    27.853933
# std      3.778023                   3.304157                     3.018129
# min     60.000000                  32.000000                    19.000000
# 25%     67.000000                  36.000000                    26.000000
# 50%     69.000000                  39.000000                    27.500000
# 75%     72.000000                  42.000000                    30.000000
# max     78.000000                  45.000000                    36.000000
#
#        porta_mala_ft3      peso_lb
# count       74.000000    86.000000
# mean        13.986486  3104.593023
# std          3.120824   600.129993
# min          6.000000  1695.000000
# 25%         12.000000  2647.500000
# 50%         14.000000  3085.000000
# 75%         16.000000  3567.500000
# max         22.000000  4105.000000

# %% [markdown]
# 7. Converta o dataframe de carros para um vetor NumPy chamado **carros**

# %%
carros = df.to_numpy()
carros
# Out:
# array([['Acura', 'Integra', 'Pequeno', ..., 2705.0, 'Fora dos EUA',
#         'Acura Integra'],
#        [nan, 'Legend', 'Médio', ..., 3560.0, 'Fora dos EUA',
#         'Acura Legend'],
#        ['Audi', '90', 'Compacto', ..., 3375.0, 'Fora dos EUA', 'Audi 90'],
#        ...,
#        ['Volkswagen', 'Corrado', 'Esportivo', ..., 2810.0,
#         'Fora dos EUA', 'Volkswagen Corrado'],
#        ['Volvo', '240', 'Compacto', ..., 2985.0, 'Fora dos EUA',
#         'Volvo 240'],
#        [nan, '850', 'Médio', ..., 3245.0, 'Fora dos EUA', 'Volvo 850']],
#       dtype=object)

# %% [markdown]
# 8. Converta o data Frame de carros para uma lista chamada **lista_carros**.

# %%
lista_carros = df.values.tolist()

# %% [markdown]
# 9. Imprima as informações básicas do Data Frame.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 93 entries, 0 to 92
# Data columns (total 27 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   fabricante                   89 non-null     object
#  1   modelo                       92 non-null     object
#  2   tipo                         90 non-null     object
#  3   preco_min                    86 non-null     float64
#  4   preco                        91 non-null     float64
#  5   preco_max                    88 non-null     float64
#  6   mpg_cidade                   84 non-null     float64
#  7   mpg_rodovia                  91 non-null     float64
#  8   airbags                      87 non-null     object
#  9   trem_forca                   86 non-null     object
#  10  cilindros                    87 non-null     float64
#  11  tamanho_motor                91 non-null     float64
#  12  horsepower                   86 non-null     float64
#  13  rpm                          90 non-null     float64
#  14  revolucoes_milha             87 non-null     float64
#  15  transmissao_manual           88 non-null     object
#  16  capacidade_tanque            85 non-null     float64
#  17  passageiros                  91 non-null     float64
#  18  comprimento_in               89 non-null     float64
#  19  distancia_eixo               92 non-null     float64
#  20  largura_in                   87 non-null     float64
#  21  espaco_inversao_marcha_ft    88 non-null     float64
#  22  tamanho_assento_traseiro_in  89 non-null     float64
#  23  porta_mala_ft3               74 non-null     float64
#  24  peso_lb                      86 non-null     float64
#  25  origem                       88 non-null     object
#  26  fabricante_modelo            90 non-null     object
# dtypes: float64(19), object(8)
# memory usage: 19.7+ KB

# %% [markdown]
# 10. Analise as informações trazidas pela função `df.info()`, comparando a informação **Range Index** com todos os valores numéricos da segunda coluna que aparece nos resultados, sem seguida, responda:
#
# > O que esses resultados podem evidenciar?
#
# **RESPOSTA**: Os resultados evidenciam que o dataframe possui 93 linhas com 27 colunas cada, porém nem sempre todas as 27 colunas estão devidamente preenchidas. Na coluna "porta_mala_ft3" por exemplo, das 93 linhas, apenas 74 possuem valores não nulos.

# %% [markdown]
# 11. Verifique se Data Frame (df) tem algum valor ausente.

# %%
print('Existem valores ausentes!') if df.isnull().values.any() else print('Não existem valores ausentes no dataframe.')
# Out:
# Existem valores ausentes!

# %% [markdown]
# 12. Qual é o número total de dados ausentes por coluna?

# %%
df.isnull().sum()
# Out:
# fabricante                      4
# modelo                          1
# tipo                            3
# preco_min                       7
# preco                           2
# preco_max                       5
# mpg_cidade                      9
# mpg_rodovia                     2
# airbags                         6
# trem_forca                      7
# cilindros                       6
# tamanho_motor                   2
# horsepower                      7
# rpm                             3
# revolucoes_milha                6
# transmissao_manual              5
# capacidade_tanque               8
# passageiros                     2
# comprimento_in                  4
# distancia_eixo                  1
# largura_in                      6
# espaco_inversao_marcha_ft       5
# tamanho_assento_traseiro_in     4
# porta_mala_ft3                 19
# peso_lb                         7
# origem                          5
# fabricante_modelo               3
# dtype: int64

# %% [markdown]
# 13. Qual é o número total de dados ausentes no Data Frame?

# %%
df.isnull().sum().sum()
# Out:
# 139

# %% [markdown]
# 14. Imprima o número total de dados ausentes em cada uma das linhas?

# %%
values = df.isnull().values
emptylines = {}

i=0
for line in values:
    emptylines[i] = line.sum()
    i += 1

for line in emptylines:
    print(f'Quantidade de dados ausentes na linha {line}: {emptylines[line]}')
# Out:
# Quantidade de dados ausentes na linha 0: 1
# Quantidade de dados ausentes na linha 1: 1
# Quantidade de dados ausentes na linha 2: 0
# Quantidade de dados ausentes na linha 3: 5
# Quantidade de dados ausentes na linha 4: 3
# Quantidade de dados ausentes na linha 5: 2
# Quantidade de dados ausentes na linha 6: 3
# Quantidade de dados ausentes na linha 7: 0
# Quantidade de dados ausentes na linha 8: 1
# Quantidade de dados ausentes na linha 9: 1
# Quantidade de dados ausentes na linha 10: 1
# Quantidade de dados ausentes na linha 11: 3
# Quantidade de dados ausentes na linha 12: 2
# Quantidade de dados ausentes na linha 13: 2
# Quantidade de dados ausentes na linha 14: 4
# Quantidade de dados ausentes na linha 15: 1
# Quantidade de dados ausentes na linha 16: 2
# Quantidade de dados ausentes na linha 17: 0
# Quantidade de dados ausentes na linha 18: 3
# Quantidade de dados ausentes na linha 19: 2
# Quantidade de dados ausentes na linha 20: 0
# Quantidade de dados ausentes na linha 21: 0
# Quantidade de dados ausentes na linha 22: 2
# Quantidade de dados ausentes na linha 23: 2
# Quantidade de dados ausentes na linha 24: 2
# Quantidade de dados ausentes na linha 25: 2
# Quantidade de dados ausentes na linha 26: 2
# Quantidade de dados ausentes na linha 27: 2
# Quantidade de dados ausentes na linha 28: 0
# Quantidade de dados ausentes na linha 29: 2
# Quantidade de dados ausentes na linha 30: 1
# Quantidade de dados ausentes na linha 31: 1
# Quantidade de dados ausentes na linha 32: 3
# Quantidade de dados ausentes na linha 33: 1
# Quantidade de dados ausentes na linha 34: 1
# Quantidade de dados ausentes na linha 35: 1
# Quantidade de dados ausentes na linha 36: 2
# Quantidade de dados ausentes na linha 37: 1
# Quantidade de dados ausentes na linha 38: 1
# Quantidade de dados ausentes na linha 39: 1
# Quantidade de dados ausentes na linha 40: 1
# Quantidade de dados ausentes na linha 41: 3
# Quantidade de dados ausentes na linha 42: 1
# Quantidade de dados ausentes na linha 43: 0
# Quantidade de dados ausentes na linha 44: 1
# Quantidade de dados ausentes na linha 45: 2
# Quantidade de dados ausentes na linha 46: 2
# Quantidade de dados ausentes na linha 47: 2
# Quantidade de dados ausentes na linha 48: 1
# Quantidade de dados ausentes na linha 49: 2
# Quantidade de dados ausentes na linha 50: 1
# Quantidade de dados ausentes na linha 51: 1
# Quantidade de dados ausentes na linha 52: 0
# Quantidade de dados ausentes na linha 53: 0
# Quantidade de dados ausentes na linha 54: 0
# Quantidade de dados ausentes na linha 55: 1
# Quantidade de dados ausentes na linha 56: 6
# Quantidade de dados ausentes na linha 57: 2
# Quantidade de dados ausentes na linha 58: 2
# Quantidade de dados ausentes na linha 59: 1
# Quantidade de dados ausentes na linha 60: 0
# Quantidade de dados ausentes na linha 61: 1
# Quantidade de dados ausentes na linha 62: 1
# Quantidade de dados ausentes na linha 63: 3
# Quantidade de dados ausentes na linha 64: 0
# Quantidade de dados ausentes na linha 65: 2
# Quantidade de dados ausentes na linha 66: 1
# Quantidade de dados ausentes na linha 67: 0
# Quantidade de dados ausentes na linha 68: 1
# Quantidade de dados ausentes na linha 69: 2
# Quantidade de dados ausentes na linha 70: 1
# Quantidade de dados ausentes na linha 71: 2
# Quantidade de dados ausentes na linha 72: 1
# Quantidade de dados ausentes na linha 73: 4
# Quantidade de dados ausentes na linha 74: 2
# Quantidade de dados ausentes na linha 75: 0
# Quantidade de dados ausentes na linha 76: 0
# Quantidade de dados ausentes na linha 77: 2
# Quantidade de dados ausentes na linha 78: 3
# Quantidade de dados ausentes na linha 79: 0
# Quantidade de dados ausentes na linha 80: 0
# Quantidade de dados ausentes na linha 81: 1
# Quantidade de dados ausentes na linha 82: 3
# Quantidade de dados ausentes na linha 83: 3
# Quantidade de dados ausentes na linha 84: 3
# Quantidade de dados ausentes na linha 85: 3
# Quantidade de dados ausentes na linha 86: 2
# Quantidade de dados ausentes na linha 87: 0
# Quantidade de dados ausentes na linha 88: 2
# Quantidade de dados ausentes na linha 89: 0
# Quantidade de dados ausentes na linha 90: 0
# Quantidade de dados ausentes na linha 91: 1
# Quantidade de dados ausentes na linha 92: 2

# %% [markdown]
# 15. Mostre as linhas que possuem dados ausentes na coluna `fabricante`.

# %%
df[df.loc[:,'fabricante'].isna()]
# Out:
#    fabricante    modelo    tipo  preco_min  preco  preco_max  mpg_cidade  \
# 1         NaN    Legend   Médio       29.2   33.9       38.7        18.0
# 19        NaN  Concorde  Grande       18.4   18.4       18.4        20.0
# 49        NaN     SC300   Médio       34.7   35.2       35.6        18.0
# 92        NaN       850   Médio       24.8   26.7       28.5        20.0
#
#     mpg_rodovia                 airbags trem_forca  ...  passageiros  \
# 1          25.0  Motorista e Passageiro  Dianteiro  ...          5.0
# 19         28.0  Motorista e Passageiro  Dianteiro  ...          6.0
# 49         23.0  Motorista e Passageiro   Traseiro  ...          4.0
# 92         28.0  Motorista e Passageiro  Dianteiro  ...          5.0
#
#     comprimento_in  distancia_eixo  largura_in  espaco_inversao_marcha_ft  \
# 1            195.0           115.0        71.0                       38.0
# 19           203.0           113.0        74.0                        NaN
# 49           191.0           106.0        71.0                       39.0
# 92           184.0           105.0        69.0                       38.0
#
#    tamanho_assento_traseiro_in  porta_mala_ft3  peso_lb        origem  \
# 1                         30.0            15.0   3560.0  Fora dos EUA
# 19                        31.0            15.0   3515.0           EUA
# 49                        25.0             9.0   3515.0  Fora dos EUA
# 92                        30.0            15.0   3245.0  Fora dos EUA
#
#     fabricante_modelo
# 1        Acura Legend
# 19  Chrylser Concorde
# 49        Lexus SC300
# 92          Volvo 850
#
# [4 rows x 27 columns]

# %% [markdown]
# 16. Substitua os valores ausentes da coluna preço por zero.

# %%
df['preco'] = df.loc[:,'preco'].fillna(0)
df[df.loc[:,'preco'].isnull()]
# Out:
# Empty DataFrame
# Columns: [fabricante, modelo, tipo, preco_min, preco, preco_max, mpg_cidade, mpg_rodovia, airbags, trem_forca, cilindros, tamanho_motor, horsepower, rpm, revolucoes_milha, transmissao_manual, capacidade_tanque, passageiros, comprimento_in, distancia_eixo, largura_in, espaco_inversao_marcha_ft, tamanho_assento_traseiro_in, porta_mala_ft3, peso_lb, origem, fabricante_modelo]
# Index: []
#
# [0 rows x 27 columns]

# %% [markdown]
# 16. Remova do Data Frame todas as linhas que possuem pelo menos um dado ausente.

# %%
df = df.dropna().reset_index(drop=True)
df.isnull().sum()
# Out:
# fabricante                     0
# modelo                         0
# tipo                           0
# preco_min                      0
# preco                          0
# preco_max                      0
# mpg_cidade                     0
# mpg_rodovia                    0
# airbags                        0
# trem_forca                     0
# cilindros                      0
# tamanho_motor                  0
# horsepower                     0
# rpm                            0
# revolucoes_milha               0
# transmissao_manual             0
# capacidade_tanque              0
# passageiros                    0
# comprimento_in                 0
# distancia_eixo                 0
# largura_in                     0
# espaco_inversao_marcha_ft      0
# tamanho_assento_traseiro_in    0
# porta_mala_ft3                 0
# peso_lb                        0
# origem                         0
# fabricante_modelo              0
# dtype: int64

# %% [markdown]
# 17. Renomeie a coluna `trem_forca` para `tracao`.

# %%
df.rename(columns = {'trem_forca':'tracao'}, inplace = True)
df
# Out:
#     fabricante      modelo       tipo  preco_min  preco  preco_max  \
# 0         Audi          90   Compacto       25.9   29.1       32.3
# 1        Buick  Roadmaster     Grande       22.6   23.7       24.9
# 2    Chevrolet     Caprice     Grande       18.0   18.8       19.6
# 3     Chrysler     LeBaron   Compacto       14.5   15.8       17.1
# 4     Chrysler    Imperial     Grande       29.5   29.5       29.5
# 5        Eagle      Summit    Pequeno        7.9   12.2       16.5
# 6      Hyundai       Excel    Pequeno        6.8    8.0        9.2
# 7        Mazda         323    Pequeno        7.4    8.3        9.1
# 8        Mazda     Protege    Pequeno       10.9   11.6       12.3
# 9        Mazda         626   Compacto       14.3   16.5       18.7
# 10     Mercury      Cougar      Médio       14.9   14.9       14.9
# 11      Nissan      Altima   Compacto       13.0   15.7       18.3
# 12  Oldsmobile     Achieva   Compacto       13.0   13.5       14.0
# 13     Pontiac  Grand_Prix      Médio       15.4   18.5       21.6
# 14     Pontiac  Bonneville     Grande       19.4   24.4       29.4
# 15      Subaru       Justy    Pequeno        7.3    8.4        9.5
# 16      Subaru      Loyale    Pequeno       10.5   10.9       11.3
# 17  Volkswagen         Fox    Pequeno        8.7    9.1        9.5
# 18  Volkswagen      Passat   Compacto       17.6   20.0       22.4
# 19  Volkswagen     Corrado  Esportivo       22.9   23.3       23.7
#
#     mpg_cidade  mpg_rodovia                 airbags     tracao  ...  \
# 0         20.0         26.0       Somente Motorista  Dianteiro  ...
# 1         16.0         25.0       Somente Motorista   Traseiro  ...
# 2         17.0         26.0       Somente Motorista   Traseiro  ...
# 3         23.0         28.0  Motorista e Passageiro  Dianteiro  ...
# 4         20.0         26.0       Somente Motorista  Dianteiro  ...
# 5         29.0         33.0                  Nenhum  Dianteiro  ...
# 6         29.0         33.0                  Nenhum  Dianteiro  ...
# 7         29.0         37.0                  Nenhum  Dianteiro  ...
# 8         28.0         36.0                  Nenhum  Dianteiro  ...
# 9         26.0         34.0       Somente Motorista  Dianteiro  ...
# 10        19.0         26.0                  Nenhum   Traseiro  ...
# 11        24.0         30.0       Somente Motorista  Dianteiro  ...
# 12        24.0         31.0                  Nenhum  Dianteiro  ...
# 13        19.0         27.0                  Nenhum  Dianteiro  ...
# 14        19.0         28.0  Motorista e Passageiro  Dianteiro  ...
# 15        33.0         37.0                  Nenhum        4WD  ...
# 16        25.0         30.0                  Nenhum        4WD  ...
# 17        25.0         33.0                  Nenhum  Dianteiro  ...
# 18        21.0         30.0                  Nenhum  Dianteiro  ...
# 19        18.0         25.0                  Nenhum  Dianteiro  ...
#
#     passageiros  comprimento_in  distancia_eixo  largura_in  \
# 0           5.0           180.0           102.0        67.0
# 1           6.0           216.0           116.0        78.0
# 2           6.0           214.0           116.0        77.0
# 3           6.0           183.0           104.0        68.0
# 4           6.0           203.0           110.0        69.0
# 5           5.0           174.0            98.0        66.0
# 6           5.0           168.0            94.0        63.0
# 7           4.0           164.0            97.0        66.0
# 8           5.0           172.0            98.0        66.0
# 9           5.0           184.0           103.0        69.0
# 10          5.0           199.0           113.0        73.0
# 11          5.0           181.0           103.0        67.0
# 12          5.0           188.0           103.0        67.0
# 13          5.0           195.0           108.0        72.0
# 14          6.0           177.0           111.0        74.0
# 15          4.0           146.0            90.0        60.0
# 16          5.0           175.0            97.0        65.0
# 17          4.0           163.0            93.0        63.0
# 18          5.0           180.0           103.0        67.0
# 19          4.0           159.0            97.0        66.0
#
#     espaco_inversao_marcha_ft tamanho_assento_traseiro_in  porta_mala_ft3  \
# 0                        37.0                        28.0            14.0
# 1                        45.0                        30.5            21.0
# 2                        42.0                        29.5            20.0
# 3                        41.0                        30.5            14.0
# 4                        44.0                        36.0            17.0
# 5                        36.0                        26.5            11.0
# 6                        35.0                        26.0            11.0
# 7                        34.0                        27.0            16.0
# 8                        36.0                        26.5            13.0
# 9                        40.0                        29.5            14.0
# 10                       38.0                        28.0            15.0
# 11                       40.0                        28.5            14.0
# 12                       39.0                        28.0            14.0
# 13                       41.0                        28.5            16.0
# 14                       43.0                        30.5            18.0
# 15                       32.0                        23.5            10.0
# 16                       35.0                        27.5            15.0
# 17                       34.0                        26.0            10.0
# 18                       35.0                        31.5            14.0
# 19                       36.0                        26.0            15.0
#
#     peso_lb        origem   fabricante_modelo
# 0    3375.0  Fora dos EUA             Audi 90
# 1    4105.0           EUA    Buick Roadmaster
# 2    3910.0           EUA   Chevrolet Caprice
# 3    3085.0           EUA    Chrysler LeBaron
# 4    3570.0           EUA   Chrysler Imperial
# 5    2295.0           EUA        Eagle Summit
# 6    2345.0  Fora dos EUA       Hyundai Excel
# 7    2325.0  Fora dos EUA           Mazda 323
# 8    2440.0  Fora dos EUA       Mazda Protege
# 9    2970.0  Fora dos EUA           Mazda 626
# 10   3610.0           EUA      Mercury Cougar
# 11   3050.0  Fora dos EUA       Nissan Altima
# 12   2910.0           EUA  Oldsmobile Achieva
# 13   3450.0           EUA  Pontiac Grand_Prix
# 14   3495.0           EUA  Pontiac Bonneville
# 15   2045.0  Fora dos EUA        Subaru Justy
# 16   2490.0  Fora dos EUA       Subaru Loyale
# 17   2240.0  Fora dos EUA      Volkswagen Fox
# 18   2985.0  Fora dos EUA   Volkswagen Passat
# 19   2810.0  Fora dos EUA  Volkswagen Corrado
#
# [20 rows x 27 columns]

# %% [markdown]
# 18. Selecione todos os dados da coluna tração.

# %%
df.loc[:,'tracao']
# Out:
# 0     Dianteiro
# 1      Traseiro
# 2      Traseiro
# 3     Dianteiro
# 4     Dianteiro
# 5     Dianteiro
# 6     Dianteiro
# 7     Dianteiro
# 8     Dianteiro
# 9     Dianteiro
# 10     Traseiro
# 11    Dianteiro
# 12    Dianteiro
# 13    Dianteiro
# 14    Dianteiro
# 15          4WD
# 16          4WD
# 17    Dianteiro
# 18    Dianteiro
# 19    Dianteiro
# Name: tracao, dtype: object

# %% [markdown]
# 19. Selecione as colunas: `fabricante`,`modelo` e `tipo`.

# %%
df.loc[:,['tracao', 'modelo', 'tipo']]
# Out:
#        tracao      modelo       tipo
# 0   Dianteiro          90   Compacto
# 1    Traseiro  Roadmaster     Grande
# 2    Traseiro     Caprice     Grande
# 3   Dianteiro     LeBaron   Compacto
# 4   Dianteiro    Imperial     Grande
# 5   Dianteiro      Summit    Pequeno
# 6   Dianteiro       Excel    Pequeno
# 7   Dianteiro         323    Pequeno
# 8   Dianteiro     Protege    Pequeno
# 9   Dianteiro         626   Compacto
# 10   Traseiro      Cougar      Médio
# 11  Dianteiro      Altima   Compacto
# 12  Dianteiro     Achieva   Compacto
# 13  Dianteiro  Grand_Prix      Médio
# 14  Dianteiro  Bonneville     Grande
# 15        4WD       Justy    Pequeno
# 16        4WD      Loyale    Pequeno
# 17  Dianteiro         Fox    Pequeno
# 18  Dianteiro      Passat   Compacto
# 19  Dianteiro     Corrado  Esportivo

# %% [markdown]
# 20. Selecione o fabricante com maior preço.

# %%
df[df.loc[:,'preco'] == df['preco'].max()].loc[:,['fabricante']]
# Out:
#   fabricante
# 4   Chrysler

# %% [markdown]
# 22. Selecione as colunas `fabricante`, `modelo` e `preco`; dos carros que cabem menos passageiros.

# %%
df[df.loc[:,'passageiros'] == df['passageiros'].min()].loc[:,['fabricante', 'modelo', 'preco']]
# Out:
#     fabricante   modelo  preco
# 7        Mazda      323    8.3
# 15      Subaru    Justy    8.4
# 17  Volkswagen      Fox    9.1
# 19  Volkswagen  Corrado   23.3

# %% [markdown]
# 23. Mostre o total de carros que existem por `tipo`.

# %%
df.loc[:,['tipo']].value_counts()
# Out:
# tipo
# Pequeno      7
# Compacto     6
# Grande       4
# Médio        2
# Esportivo    1
# dtype: int64

# %% [markdown]
# 24. Na coluna `tracao`, substitua *4WD* por *4X4*.

# %%
df['tracao'] = df.loc[:,['tracao']].replace('4WD', '4X4')
df.loc[:,['tracao']].value_counts()
# Out:
# tracao
# Dianteiro    15
# Traseiro      3
# 4X4           2
# dtype: int64

# %% [markdown]
# 25. Converta a coluna `cilintros` para `int`.

# %%
df['cilindros'] = df['cilindros'].astype('int8')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 27 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   fabricante                   20 non-null     object
#  1   modelo                       20 non-null     object
#  2   tipo                         20 non-null     object
#  3   preco_min                    20 non-null     float64
#  4   preco                        20 non-null     float64
#  5   preco_max                    20 non-null     float64
#  6   mpg_cidade                   20 non-null     float64
#  7   mpg_rodovia                  20 non-null     float64
#  8   airbags                      20 non-null     object
#  9   tracao                       20 non-null     object
#  10  cilindros                    20 non-null     int8
#  11  tamanho_motor                20 non-null     float64
#  12  horsepower                   20 non-null     float64
#  13  rpm                          20 non-null     float64
#  14  revolucoes_milha             20 non-null     float64
#  15  transmissao_manual           20 non-null     object
#  16  capacidade_tanque            20 non-null     float64
#  17  passageiros                  20 non-null     float64
#  18  comprimento_in               20 non-null     float64
#  19  distancia_eixo               20 non-null     float64
#  20  largura_in                   20 non-null     float64
#  21  espaco_inversao_marcha_ft    20 non-null     float64
#  22  tamanho_assento_traseiro_in  20 non-null     float64
#  23  porta_mala_ft3               20 non-null     float64
#  24  peso_lb                      20 non-null     float64
#  25  origem                       20 non-null     object
#  26  fabricante_modelo            20 non-null     object
# dtypes: float64(18), int8(1), object(8)
# memory usage: 4.2+ KB

# %% [markdown]
# 26. Crie um ranking com os top 10 carros mais caros

# %%
ranking = df.sort_values(['preco'], ascending = False).head(10)
ranking
# Out:
#     fabricante      modelo       tipo  preco_min  preco  preco_max  \
# 4     Chrysler    Imperial     Grande       29.5   29.5       29.5
# 0         Audi          90   Compacto       25.9   29.1       32.3
# 14     Pontiac  Bonneville     Grande       19.4   24.4       29.4
# 1        Buick  Roadmaster     Grande       22.6   23.7       24.9
# 19  Volkswagen     Corrado  Esportivo       22.9   23.3       23.7
# 18  Volkswagen      Passat   Compacto       17.6   20.0       22.4
# 2    Chevrolet     Caprice     Grande       18.0   18.8       19.6
# 13     Pontiac  Grand_Prix      Médio       15.4   18.5       21.6
# 9        Mazda         626   Compacto       14.3   16.5       18.7
# 3     Chrysler     LeBaron   Compacto       14.5   15.8       17.1
#
#     mpg_cidade  mpg_rodovia                 airbags     tracao  ...  \
# 4         20.0         26.0       Somente Motorista  Dianteiro  ...
# 0         20.0         26.0       Somente Motorista  Dianteiro  ...
# 14        19.0         28.0  Motorista e Passageiro  Dianteiro  ...
# 1         16.0         25.0       Somente Motorista   Traseiro  ...
# 19        18.0         25.0                  Nenhum  Dianteiro  ...
# 18        21.0         30.0                  Nenhum  Dianteiro  ...
# 2         17.0         26.0       Somente Motorista   Traseiro  ...
# 13        19.0         27.0                  Nenhum  Dianteiro  ...
# 9         26.0         34.0       Somente Motorista  Dianteiro  ...
# 3         23.0         28.0  Motorista e Passageiro  Dianteiro  ...
#
#     passageiros  comprimento_in  distancia_eixo  largura_in  \
# 4           6.0           203.0           110.0        69.0
# 0           5.0           180.0           102.0        67.0
# 14          6.0           177.0           111.0        74.0
# 1           6.0           216.0           116.0        78.0
# 19          4.0           159.0            97.0        66.0
# 18          5.0           180.0           103.0        67.0
# 2           6.0           214.0           116.0        77.0
# 13          5.0           195.0           108.0        72.0
# 9           5.0           184.0           103.0        69.0
# 3           6.0           183.0           104.0        68.0
#
#     espaco_inversao_marcha_ft tamanho_assento_traseiro_in  porta_mala_ft3  \
# 4                        44.0                        36.0            17.0
# 0                        37.0                        28.0            14.0
# 14                       43.0                        30.5            18.0
# 1                        45.0                        30.5            21.0
# 19                       36.0                        26.0            15.0
# 18                       35.0                        31.5            14.0
# 2                        42.0                        29.5            20.0
# 13                       41.0                        28.5            16.0
# 9                        40.0                        29.5            14.0
# 3                        41.0                        30.5            14.0
#
#     peso_lb        origem   fabricante_modelo
# 4    3570.0           EUA   Chrysler Imperial
# 0    3375.0  Fora dos EUA             Audi 90
# 14   3495.0           EUA  Pontiac Bonneville
# 1    4105.0           EUA    Buick Roadmaster
# 19   2810.0  Fora dos EUA  Volkswagen Corrado
# 18   2985.0  Fora dos EUA   Volkswagen Passat
# 2    3910.0           EUA   Chevrolet Caprice
# 13   3450.0           EUA  Pontiac Grand_Prix
# 9    2970.0  Fora dos EUA           Mazda 626
# 3    3085.0           EUA    Chrysler LeBaron
#
# [10 rows x 27 columns]

# %% [markdown]
# 27. Exiba uma contagem de valores por tipo de câmbio e tipo de veículo.

# %%
print('- Contagem por tipo de veículo:')
print(df.loc[:,['tipo']].value_counts())
print('\n- Contagem por tipo de câmbio (manual = "sim" ou automático = "não"):')
print(df.loc[:,['transmissao_manual']].value_counts())
print('\n-  Relação entre câmbio e tipo de veículo: ')
print(df.loc[:,['tipo', 'transmissao_manual']].value_counts())
# Out:
# - Contagem por tipo de veículo:
# tipo
# Pequeno      7
# Compacto     6
# Grande       4
# Médio        2
# Esportivo    1
# dtype: int64
#
# - Contagem por tipo de câmbio (manual = "sim" ou automático = "não"):
# transmissao_manual
# Sim                   13
# Não                    7
# dtype: int64
#
# -  Relação entre câmbio e tipo de veículo:
# tipo       transmissao_manual
# Pequeno    Sim                   7
# Compacto   Sim                   4
# Grande     Não                   4
# Compacto   Não                   2
# Esportivo  Sim                   1
# Médio      Não                   1
#            Sim                   1
# dtype: int64
